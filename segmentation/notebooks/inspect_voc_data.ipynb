# %%
import os
from pathlib import Path
from PIL import Image 
import numpy as np
import matplotlib.pyplot as plt

# %%
sample_img_path = "../data/VOCdevkit/VOC2012/SegmentationClass/2007_000129.png"

# Show the image
img = Image.open(sample_img_path)
plt.imshow(img)

# %%
img_np = np.array(img)

img_np.shape, img_np.dtype
# Out:
# ((500, 334), dtype('uint8'))

# %%
np.unique(img_np)
# Out:
# array([  0,   2,  15, 255], dtype=uint8)
